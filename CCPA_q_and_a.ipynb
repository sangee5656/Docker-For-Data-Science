# %% [markdown]
# <a href="https://colab.research.google.com/github/sangee5656/Docker-For-Data-Science/blob/main/CCPA_q_and_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install gradio

# %%
# import gradio as gr
# def sketch_recognition(img):
#     pass# Implement your sketch recog model here...

# gr.Interface(fn=sketch_recognition, inputs="sketchpad", outputs="label").launch()

# %%
# ! pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 46.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.6 MB/s eta 0:00:00

# %%
# %%writefile app.py
# import streamlit as st
# st.write('# Hello World')
# st.write('# Run streamlit without ngrok on colab using localtunnel')
# Out:
# Writing app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.148.222.45:8501
#
#   Stopping...
# ^C

# %%
# !pip install -q google-generativeai

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.2/374.2 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade langchain langchain_community

# %%
import pprint
import google.generativeai as palm

# %%
# !pip install --upgrade langchain

# %%
from langchain.llms import GooglePalm

api_key = 'AIzaSyA1MkqRZgiVviARI6KRxak21A4ulnPUTRA' # get this free api key from https://makersuite.google.com/

llm = GooglePalm(google_api_key=api_key, temperature=0.7) # Try instantiating the GooglePalm object again after upgrading

# %%
poem = llm("Write a 4 line poem of my love for sangeetha")
print(poem)
# Out:
# Sangeetha is my passion,
# My heart and soul, my reason,
# To sing and dance and play,
# Is all I live for every day.

# %%
from langchain.chains import RetrievalQA


from langchain.embeddings import GooglePalmEmbeddings
from langchain.llms import GooglePalm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Read the CSV file
file_path = "/content/drive/MyDrive/Colab Notebooks/Langchain/ccpa_faqs.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Display the first few rows of the dataframe
print(df.head())

# Display the column names
print(df.columns)
# Out:
#                                               prompt  \
# 0  What is the California Consumer Privacy Act (C...
# 1                                    Who is covered?
# 2  As a California resident, what types of reques...
# 3        What information is covered under the CCPA?
# 4  Why are you asking me to provide information t...
#
#                                             response
# 0  The California Consumer Privacy Act (CCPA) pro...
# 1  All California residents. If you are unsure if...
# 2  Residents can request to access, delete, or co...
# 3  The CCPA covers Personal Information. Personal...
# 4  The information you provide helps us identify ...
# Index(['prompt', 'response'], dtype='object')

# %%
# from langchain.document_loaders.csv_loader import CSVLoader

# loader = CSVLoader(file_path="/content/drive/MyDrive/Colab Notebooks/Langchain/codebasics.csv", source_column="prompt", encoding="ISO-8859-1")

# # Store the loaded data in the 'data' variable
# data = loader.load()

from langchain.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path="/content/drive/MyDrive/Colab Notebooks/Langchain/ccpa_faqs.csv", source_column="prompt", encoding="ISO-8859-1")

# Store the loaded data in the 'data' variable
data = loader.load()

# %%
print(data)
# Out:
# [Document(metadata={'source': 'What is the California Consumer Privacy Act (CCPA)?', 'row': 0}, page_content='prompt: What is the California Consumer Privacy Act (CCPA)?\nresponse: The California Consumer Privacy Act (CCPA) provides residents of California specific rights regarding their Personal Information.'), Document(metadata={'source': 'Who is covered?', 'row': 1}, page_content='prompt: Who is covered?\nresponse: All California residents. If you are unsure if you are a resident, you can visit\xa0https://www.ftb.ca.gov/file/personal/residency-status/index.html\xa0for more information.'), Document(metadata={'source': 'As a California resident, what types of requests can I make?', 'row': 2}, page_content='prompt: As a California resident, what types of requests can I make?\nresponse: Residents can request to access, delete, or correct their Personal Information. Residents can also opt out of the sale/sharing of their Personal Information (including for targeted advertising) and lim
# ...

# %%
# !pip install InstructorEmbedding

# %%
# !pip install sentence-transformers==2.2.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !pip install --upgrade langchain sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 9.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 2.2.2
#     Uninstalling sentence-transformers-2.2.2:
#       Successfully uninstalled sentence-transformers-2.2.2
# ...

# %%
# !pip install langchain sentence-transformers InstructorEmbedding

# %%
# !pip install langchain

# %%
# !pip install python-dotenv==1.0.0

# %%
# !pip install streamlit==1.22.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 90.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 82.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.2 MB/s eta 0:00:00
# ...

# %%
# !pip install tiktoken==0.4.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.6 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-cpu==1.7.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 51.7 MB/s eta 0:00:00
# ...

# %%
# !pip install protobuf

# %%
# !pip uninstall -y InstructorEmbedding sentence-transformers
# Out:
# Found existing installation: InstructorEmbedding 1.0.1
# Uninstalling InstructorEmbedding-1.0.1:
#   Successfully uninstalled InstructorEmbedding-1.0.1
# Found existing installation: sentence-transformers 3.0.1
# Uninstalling sentence-transformers-3.0.1:
#   Successfully uninstalled sentence-transformers-3.0.1

# %%
# !pip install sentence-transformers==2.2.2
# !pip install InstructorEmbedding
# Out:
# ...
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# ...
#   Using cached InstructorEmbedding-1.0.1-py2.py3-none-any.whl.metadata (20 kB)
# Using cached InstructorEmbedding-1.0.1-py2.py3-none-any.whl (19 kB)
# ...

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

embeddings = HuggingFaceInstructEmbeddings(
    model_name="hkunlp/instructor-large",
    query_instruction="Represent the query for retrieval: "
)

e = embeddings.embed_query("If I delete my personal information what will i lose?")
print(e)
#############
# from sentence_transformers import SentenceTransformer

# # Initialize the model
# model = SentenceTransformer('hkunlp/instructor-large')

# # Embed a query
# e = model.encode("What is your refund policy?")
# print(e)
#################
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# ...

# %%
len(e)
# Out:
# 768

# %%
e[:5]
# Out:
# [-0.0070535894483327866,
#  0.003199047641828656,
#  -0.013838478364050388,
#  -0.0019682375714182854,
#  0.018320232629776]

# %%
from langchain.vectorstores import FAISS

# Create a FAISS instance for vector database from 'data'
vectordb = FAISS.from_documents(documents=data,
                                 embedding=embeddings)

# Create a retriever for querying the vector database
retriever = vectordb.as_retriever(score_threshold = 0.7)

# %%
rdocs = retriever.get_relevant_documents("What is delete my personal info?")
rdocs
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# [Document(metadata={'source': 'What does it mean to delete my Personal Information?', 'row': 20}, page_content='prompt: What does it mean to delete my Personal Information?\nresponse: The right of deletion allows you to request that we delete Personal Information we have collected from you.'),
# ...

# %%
#We are all set 👍🏼 Let's ask some questions now

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "response" section in the source document context without making much changes.
If the answer is not found in the context, kindly state "I don't know." Don't try to make up an answer.

CONTEXT: {context}

QUESTION: {question}"""


PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)
chain_type_kwargs = {"prompt": PROMPT}


from langchain.chains import RetrievalQA

chain = RetrievalQA.from_chain_type(llm=llm,
                            chain_type="stuff",
                            retriever=retriever,
                            input_key="query",
                            return_source_documents=True,
                            chain_type_kwargs=chain_type_kwargs)

# %%
chain("How does the CCPA define personal information?")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ERROR:tornado.access:500 POST /v1beta/models/text-bison-001:generateText?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 3605.26ms
# WARNING:langchain_core.language_models.llms:Retrying langchain_community.llms.google_palm.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised InternalServerError: 500 POST https://generativelanguage.googleapis.com/v1beta/models/text-bison-001:generateText?%24alt=json%3Benum-encoding%3Dint: An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting.
# {'query': 'How does the CCPA define personal information?',
# ...

# %%
chain("What are the main rights granted to consumers under the CCPA?")
# Out:
# {'query': 'What are the main rights granted to consumers under the CCPA?',
#  'result': 'The California Consumer Privacy Act (CCPA) provides residents of California specific rights regarding their Personal Information, including:\n\nThe right to know what Personal Information is collected about you and how it is used.\nThe right to access your Personal Information.\nThe right to correct inaccurate Personal Information.\nThe right to delete your Personal Information.\nThe right to opt out of the sale of your Personal Information.\nThe right to opt out of receiving targeted advertising.',
#  'source_documents': [Document(metadata={'source': 'What is the California Consumer Privacy Act (CCPA)?', 'row': 0}, page_content='prompt: What is the California Consumer Privacy Act (CCPA)?\nresponse: The California Consumer Privacy Act (CCPA) provides residents of California specific rights regarding their Personal Information.'),
# ...

# %%
chain("How can consumers exercise their rights under the CCPA?")
# Out:
# {'query': 'How can consumers exercise their rights under the CCPA?',
#  'result': 'response: California residents may exercise their CCPA rights by submitting a request to us via this website.',
#  'source_documents': [Document(metadata={'source': 'What is the California Consumer Privacy Act (CCPA)?', 'row': 0}, page_content='prompt: What is the California Consumer Privacy Act (CCPA)?\nresponse: The California Consumer Privacy Act (CCPA) provides residents of California specific rights regarding their Personal Information.'),
# ...

# %%
#questions


# What are the main rights granted to consumers under the CCPA?
# How does the CCPA define "personal information"?
# What businesses are required to comply with the CCPA?
# What are the penalties for non-compliance with the CCPA?
# How can consumers exercise their rights under the CCPA?
# What is the role of the California Attorney General in enforcing the CCPA?
# How does the CCPA impact data collection practices of businesses?
# What are the requirements for businesses to provide a "Do Not Sell My Personal Information" link?
# How does the CCPA differ from the GDPR?
# What are the exemptions under the CCPA for certain types of data or businesses?

# %%
#pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# accelerate                       0.32.1
# aiohttp                          3.9.5
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.7.0
# anyio                            3.7.1
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.1.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.15.0
# ...
